# %%
# Import the necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset into a pandas DataFrame
df = pd.read_csv('hr_seattle.csv')

# Clean the data by removing any missing values or outliers
df.dropna(inplace=True)
df = df[df['salary'] > 0]

# Use data visualization techniques to explore the relationship between salary and various factors
sns.boxplot(x='gender', y='salary', data=df)
plt.title('Salary by Gender')
plt.show()

sns.boxplot(x='race', y='salary', data=df)
plt.title('Salary by Race')
plt.show()

sns.scatterplot(x='total_exper', y='salary', data=df)
plt.title('Salary by Total Experience')
plt.show()

sns.scatterplot(x='company_exper', y='salary', data=df)
plt.title('Salary by Company Experience')
plt.show()

sns.boxplot(x='education', y='salary', data=df)
plt.title('Salary by Education')
plt.show()

# Analyze the results and draw conclusions about whether or not there is any discrimination based on gender or race
# Based on the visualizations, it appears that there may be some discrimination based on gender and race. The average salaries of male employees are higher than female employees, and the average salaries of white and Asian employees are higher than those of Black and Hispanic employees. However, further analysis is needed to confirm these observations and identify the factors contributing to these disparities.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data into a pandas DataFrame
df = pd.read_csv('hr_seattle.csv')

# Create a stacked bar chart showing the distribution of salary by race and education level
plt.figure(figsize=(10,6))
df.groupby(['race', 'education'])['salary'].mean().unstack().plot(kind='bar', stacked=True)
plt.xlabel('Race')
plt.ylabel('Average Salary')
plt.title('Average Salary by Race and Education')
plt.legend(title='Education Level')
plt.show()

# %%
import pandas as pd
import seaborn as sns

# Load the data into a pandas DataFrame
df = pd.read_csv('hr_seattle.csv')

# Create a heatmap showing the correlation between salary, total experience, and company experience
corr = df[['salary', 'total_exper', 'company_exper']].corr()
sns.heatmap(corr, cmap='coolwarm', annot=True, vmin=-1, vmax=1)
plt.title('Correlation Heatmap')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data into a pandas DataFrame
df = pd.read_csv('hr_seattle.csv')

# Create a distribution plot of salary using seaborn
sns.histplot(df['salary'], kde=True)
plt.xlabel('Salary')
plt.ylabel('Count')
plt.title('Distribution of Salary')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data into a pandas DataFrame
df = pd.read_csv('hr_seattle.csv')

# Create a scatterplot showing the relationship between salary and total experience
sns.scatterplot(x='total_exper', y='salary', data=df)
plt.xlabel('Total Experience (Years)')
plt.ylabel('Salary')
plt.title('Salary vs Total Experience')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data into a pandas DataFrame
df = pd.read_csv('hr_seattle.csv')

# Create a boxplot showing the distribution of salary by gender
sns.boxplot(x='gender', y='salary', data=df)
plt.xlabel('Gender')
plt.ylabel('Salary')
plt.title('Salary by Gender')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data into a pandas DataFrame
df = pd.read_csv('hr_seattle.csv')

# Create a violin plot showing the distribution of salary by race
sns.violinplot(x='race', y='salary', data=df)
plt.xlabel('Race')
plt.ylabel('Salary')
plt.title('Salary by Race')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data into a pandas DataFrame
df = pd.read_csv('hr_seattle.csv')

# Create a swarm plot showing the distribution of salary by gender and race
sns.swarmplot(x='gender', y='salary', hue='race', data=df, size=3)
plt.xlabel('Gender')
plt.ylabel('Salary')
plt.title('Salary by Gender and Race')
plt.legend(title='Race')
plt.show()
# Out:
# /Users/joel/anaconda3/lib/python3.10/site-packages/seaborn/categorical.py:3544: UserWarning: 54.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/joel/anaconda3/lib/python3.10/site-packages/seaborn/categorical.py:3544: UserWarning: 10.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/joel/anaconda3/lib/python3.10/site-packages/seaborn/categorical.py:3544: UserWarning: 59.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/joel/anaconda3/lib/python3.10/site-packages/seaborn/categorical.py:3544: UserWarning: 17.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
